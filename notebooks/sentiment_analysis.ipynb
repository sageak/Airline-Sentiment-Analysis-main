# %% [markdown]
# ## Airline Sentiment Analysis

# %% [markdown]
# #### Import Libraries

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score, precision_score, recall_score, confusion_matrix
from xgboost import XGBClassifier


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.metrics import AUC
from keras.utils import to_categorical
from gensim.models import Word2Vec


import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %% [markdown]
# #### Load data

# %%
# Load data
data = pd.read_csv('../data/Tweets.csv')
data.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %% [markdown]
# #### Data Exploration and Preprocessing

# %%
# Check nulls and dtypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      14640 non-null  int64
#  1   airline_sentiment             14640 non-null  object
#  2   airline_sentiment_confidence  14640 non-null  float64
#  3   negativereason                9178 non-null   object
#  4   negativereason_confidence     10522 non-null  float64
#  5   airline                       14640 non-null  object
#  6   airline_sentiment_gold        40 non-null     object
#  7   name                          14640 non-null  object
#  8   negativereason_gold           32 non-null     object
#  9   retweet_count                 14640 non-null  int64
#  10  text                          14640 non-null  object
#  11  tweet_coord                   1019 non-null   object
#  12  tweet_created                 14640 non-null  object
#  13  tweet_location                9907 non-null   object
#  14  user_timezone                 9820 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 1.7+ MB

# %%
# Check descriptive statistics
data.describe(include=[object]).T
# Out:
#                         count unique                         top  freq
# airline_sentiment       14640      3                    negative  9178
# negativereason           9178     10      Customer Service Issue  2910
# airline                 14640      6                      United  3822
# airline_sentiment_gold     40      3                    negative    32
# name                    14640   7701                 JetBlueNews    63
# negativereason_gold        32     13      Customer Service Issue    12
# text                    14640  14427              @united thanks     6
# tweet_coord              1019    832                  [0.0, 0.0]   164
# tweet_created           14640  14247   2015-02-24 09:54:34 -0800     5
# tweet_location           9907   3081                  Boston, MA   157
# user_timezone            9820     85  Eastern Time (US & Canada)  3744

# %%
# Extract postice and negatives reviews
data = data.loc[data['airline_sentiment']!= 'neutral']
data = data[["airline_sentiment", "text"]]
data['airline_sentiment'] = data['airline_sentiment'].map({'positive': 1, 'negative': 0})
data
# Out:
#        airline_sentiment                                               text
# 1                      1  @VirginAmerica plus you've added commercials t...
# 3                      0  @VirginAmerica it's really aggressive to blast...
# 4                      0  @VirginAmerica and it's a really big bad thing...
# 5                      0  @VirginAmerica seriously would pay $30 a fligh...
# 6                      1  @VirginAmerica yes, nearly every time I fly VX...
# ...                  ...                                                ...
# 14633                  0  @AmericanAir my flight was Cancelled Flightled...
# 14634                  0         @AmericanAir right on cue with the delays👌
# 14635                  1  @AmericanAir thank you we got on a different f...
# 14636                  0  @AmericanAir leaving over 20 minutes Late Flig...
# 14638                  0  @AmericanAir you have my money, you change my ...
#
# [11541 rows x 2 columns]

# %%
# Download stopwords 
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Initialize Lemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /Users/jacob/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Function to preprocess and clean text 
def preprocess_text(text):
    # Normalize and remove specaial characters
    text = text.lower()
    text = re.sub('[^0-9a-zA-Z]', ' ', text)
    # Split text and remove stop words
    words = word_tokenize(text)
    words = [word for word in words if word not in stop_words]
    # Lemmatize words
    words = [lemmatizer.lemmatize(word) for word in words]
    words = ' '.join(words)
    return words


# Preprocess text data
data['text'] = data['text'].apply(preprocess_text)

# %%
data['text'].iloc[0:5]
# Out:
# 1    virginamerica plus added commercial experience...
# 3    virginamerica really aggressive blast obnoxiou...
# 4                   virginamerica really big bad thing
# 5    virginamerica seriously would pay 30 flight se...
# 6    virginamerica yes nearly every time fly vx ear...
# Name: text, dtype: object

# %%
# Extract text and labels 
texts = data['text'].tolist()
labels = data['airline_sentiment'].tolist()

# %%
# Create a countplot
sns.set(style="darkgrid")
palette = {1: '#636efa', 0: '#f45353'}  # Define colors for each sentiment
sns.countplot(x=labels, palette=palette)

plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Distribution of Sentiments')
# Out:
# Text(0.5, 1.0, 'Distribution of Sentiments')

# %%
# Calculate the lengths of the reviews
positive_lengths = [len(text) for text, label in zip(texts, labels) if label == 1]
negative_lengths = [len(text) for text, label in zip(texts, labels) if label == 0]

# Create distplot
sns.distplot(positive_lengths, label='Positive', color='blue')
sns.distplot(negative_lengths, label='Negative',color='red')

plt.xlabel('Review Length')
plt.ylabel('Density')
plt.title('Distribution of Review Lengths by Sentiment')
plt.legend()

plt.show()

# %%
from wordcloud import WordCloud

# Combine all texts into a single string
all_text = ' '.join(texts)

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Display the generated word cloud image
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')

# Show the plot
plt.show()

# %% [markdown]
# #### Vectorization

# %%
# Initialize the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=5000)

# Fit and transform
X = tfidf_vectorizer.fit_transform(texts)


# Split data
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.3, random_state=42)

# %% [markdown]
# #### Model Experimentation

# %%
# Intialize Random Forest model
rf = RandomForestClassifier(random_state=42)

# Train the model
rf.fit(X_train, y_train)

# Evaluate model
accuracy = rf.score(X_test, y_test)
print(f'Accuracy - Random Forest: {accuracy * 100:.2f}%')
# Out:
# Accuracy - Random Forest: 90.18%

# %%
# Intialize XgboostClassifier 
xgb_model = XGBClassifier(random_state=42)

# Train the model
xgb_model.fit(X_train, y_train)

# Evaluate model
accuracy = xgb_model.score(X_test, y_test)
print(f'Accuracy - XGBoostClassifier: {accuracy * 100:.2f}%')
# Out:
# Accuracy - XGBoostClassifier: 90.33%

# %%
# Hyperparameter tuning using GridSearchCV

# Define parameter grid
param_grid = {
    'max_depth': [3, 4, 5],
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 0.9, 1.0],
    'gamma': [0, 1, 5]
}

# %%
# Initialize XgboostClassifier 
xgb_model = XGBClassifier(random_state=42)

# Initialize GridSearchCV with scoring set to 'roc_auc'
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, scoring='roc_auc', cv=3)

# Train the GridSearch
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=42, ...),
#              param_grid={'gamma': [0, 1, 5], 'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='roc_auc')

# %%
# Get the best parameters and model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Save the model
import joblib
joblib.dump(best_model, '../models/best_model.pkl')
# Out:
# ['../models/best_model.pkl']

# %%
# Load the model
best_model = joblib.load('../models/best_model.pkl')

# Evaluate the model
accuracy = best_model.score(X_test, y_test)
print(f'Accuracy of XGBoost: {accuracy * 100:.2f}%')
print(f'Best Hyperparameters: {best_params}')
# Out:
# Accuracy of XGBoost: 90.50%
# Best Hyperparameters: {'gamma': 1, 'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 300, 'subsample': 1.0}

# %% [markdown]
# #### Model Evalutation

# %%
from sklearn.metrics import roc_curve, auc

# get the predicted probabilities of class 1
predicted = best_model.predict_proba(X_test)[:,1] 

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, predicted)

# Calculate AUC
roc_auc = auc(fpr, tpr)

# Plot ROC curve
sns.set_style("darkgrid")
roc_df = pd.DataFrame({'fpr': fpr, 'tpr': tpr})
sns.lineplot(data=roc_df, x='fpr', y='tpr', color='blue', label=f'AUC={roc_auc:.4f}')
sns.lineplot(x=[0, 1], y=[0, 1], color='gray', linestyle='--')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %%
# Display confusion matrix
label_name=["negative","Positive"]
y_pred = best_model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,5))
sns.heatmap(data=cm,linewidths=.5, annot=True,  cmap = 'Blues', xticklabels=label_name, yticklabels=label_name)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = f'Accuracy Score for XGBoost Classifier: {best_model.score(X_test, y_test)}'
plt.title(all_sample_title, size = 15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score for XGBoost Classifier: 0.9049956684955242')

# %% [markdown]
# #### Model Prediction

# %%
# Make predictions
predictions = best_model.predict(X_test)

# Create a list of positive and negative sentences based on predicted labels 
positive_sentences = [X_test[i] for i in range(len(predictions)) if predictions[i] == 1]
negative_sentences = [X_test[i] for i in range(len(predictions)) if predictions[i] == 0]

# Convert the sentences back to their original text form
positive_texts = [tfidf_vectorizer.inverse_transform(sentence)[0] for sentence in positive_sentences]
negative_texts = [tfidf_vectorizer.inverse_transform(sentence)[0] for sentence in negative_sentences]

# Print the first 5 positive and negative texts
print("Positive Texts:")
for text in positive_texts[:5]:
    print(' '.join(text))

print("\nNegative Texts:")
for text in negative_texts[:5]:
    print(' '.join(text))
# Out:
# Positive Texts:
# co flight great http jetblue view
# ago airport busiest club month none one thank united weird
# americanair followed great thanks
# got thanks united
# alex booking cancelled customer flight flighted getting help patient problem reflight rep service southwestair thx tmrw
#
# Negative Texts:
# cancelled charged flight flightled unbelievable usairways
# actually agent awful booking flight gate line missed problem reflight rude standing sti united waiting
# 200 aa additional americanair asleep back called everything fee flightr gr8 hr late standard took worry
# 2015 airline brother country cross cup flight help lost luggage panamerican please sunday united
# flow hard keeping making positive smoothly sure thing usairways work

# %% [markdown]
# ### Deep Learning approach

# %% [markdown]
# #### Tokenization

# %%
# Tokenize the text data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

# Create sequences 
sequences = tokenizer.texts_to_sequences(texts)
max_seq_len = max([len(seq) for seq in sequences])
X = pad_sequences(sequences, maxlen=max_seq_len, padding='post')

# %% [markdown]
# #### Word2Vec Embeddings

# %%
# Create list of tokenized sentences 
sentences = [text.split() for text in texts]

embedding_dim = 100

# Initialize and train Word2Vec model
word2vec = Word2Vec(
    sentences, 
    vector_size=embedding_dim, 
    window=5,
    min_count=1,
    sg=0
)

# %%
# Check similar words
sims = word2vec.wv.most_similar('american', topn=10)
sims
# Out:
# [('company', 0.9993128180503845),
#  ('always', 0.9993094801902771),
#  ('southwest', 0.9992560148239136),
#  ('virginamerica', 0.9992120862007141),
#  ('aa', 0.9991614818572998),
#  ('sure', 0.9991570115089417),
#  ('complaint', 0.9991415739059448),
#  ('world', 0.9991337656974792),
#  ('good', 0.9991117715835571),
#  ('happy', 0.9990882873535156)]

# %%
# Create embedding matrix
embedding_matrix = np.zeros((len(tokenizer.word_index) + 1, embedding_dim))
for word, i in tokenizer.word_index.items():
    if word in word2vec.wv:
        embedding_matrix[i] = word2vec.wv[word] # add vector representation to embedding matrix

embedding_matrix
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-9.29091275e-01,  9.75519419e-01, -2.59096324e-02, ...,
#         -1.79014951e-01,  3.26872975e-01, -2.79811323e-01],
#        [-7.40844905e-01,  7.98023045e-01, -2.27092639e-01, ...,
#         -4.87336129e-01,  4.08085614e-01, -8.77883956e-02],
#        ...,
#        [ 1.91211569e-04, -1.92268286e-04, -1.08556841e-02, ...,
#         -8.21990077e-04, -1.88292039e-03,  1.73265173e-03],
#        [-1.25851147e-02,  1.05897030e-02, -1.29984198e-02, ...,
#          6.13694021e-04,  1.00288512e-02, -1.28102733e-03],
#        [-3.49207968e-03,  6.17052801e-03, -4.12610918e-03, ...,
#         -1.25999218e-02,  1.69337057e-02, -1.05907433e-02]])

# %% [markdown]
# #### LSTM Model

# %%
# Define the model
model = Sequential([
    Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=embedding_dim,
                weights=[embedding_matrix], input_length=max_seq_len, trainable=False),
    LSTM(64, return_sequences=True),
    LSTM(64, return_sequences=False),
    Dropout(0.2),
    Dense(2, activation="softmax")
])
# Out:
# Metal device set to: Apple M1 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2023-09-08 22:07:22.178042: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-09-08 22:07:22.178169: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 26, 100)           1175500
#
#  lstm (LSTM)                 (None, 26, 64)            42240
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 1,250,894
# Trainable params: 75,394
# Non-trainable params: 1,175,500
# _________________________________________________________________

# %%
# Compile model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=['accuracy', AUC()])

# %%
# One hot encode labels
y = to_categorical(labels, num_classes=2)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Train the model
history = model.fit(X_train,
                    y_train, 
                    validation_data=(X_test, y_test),
                    epochs=10,
                    batch_size=32)
# Out:
# Epoch 1/10
# 2023-09-08 22:07:22.700755: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-09-08 22:07:23.665098: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-09-08 22:07:23.978958: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-09-08 22:07:24.108019: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-09-08 22:07:24.409388: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#   1/271 [..............................] - ETA: 9:23 - loss: 0.6982 - accuracy: 0.2500 - auc: 0.1792
# 2023-09-08 22:07:24.637816: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 271/271 [==============================] - ETA: 0s - loss: 0.4481 - accuracy: 0.7970 - auc: 0.8729
# 2023-09-08 22:07:34.047943: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-09-08 22:07:34.150025: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-09-08 22:07:34.232889: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 271/271 [==============================] - 13s 42ms/step - loss: 0.4481 - accuracy: 0.7970 - auc: 0.8729 - val_loss: 0.4073 - val_accuracy: 0.8243 - val_auc: 0.8966
# Epoch 2/10
# 271/271 [==============================] - 10s 37ms/step - loss: 0.4203 - accuracy: 0.8076 - auc: 0.8891 - val_loss: 0.3951 - val_accuracy: 0.8330 - val_auc: 0.9038
# Epoch 3/10
# 271/271 [==============================] - 10s 37ms/step - loss: 0.4080 - accuracy: 0.8158 - auc: 0.8957 - val_loss: 0.3826 - val_accuracy: 0.8382 - val_auc: 0.9097
# Epoch 4/10
# 271/271 [==============================] - 10s 37ms/step - loss: 0.4005 - accuracy: 0.8243 - auc: 0.8996 - val_loss: 0.3898 - val_accuracy: 0.8347 - val_auc: 0.9099
# Epoch 5/10
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3860 - accuracy: 0.8334 - auc: 0.9072 - val_loss: 0.3632 - val_accuracy: 0.8496 - val_auc: 0.9213
# Epoch 6/10
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3773 - accuracy: 0.8391 - auc: 0.9116 - val_loss: 0.3491 - val_accuracy: 0.8548 - val_auc: 0.9262
# Epoch 7/10
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3649 - accuracy: 0.8461 - auc: 0.9171 - val_loss: 0.3489 - val_accuracy: 0.8489 - val_auc: 0.9260
# Epoch 8/10
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3590 - accuracy: 0.8468 - auc: 0.9204 - val_loss: 0.3328 - val_accuracy: 0.8614 - val_auc: 0.9324
# Epoch 9/10
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3573 - accuracy: 0.8459 - auc: 0.9212 - val_loss: 0.3329 - val_accuracy: 0.8607 - val_auc: 0.9339
# Epoch 10/10
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3460 - accuracy: 0.8519 - auc: 0.9264 - val_loss: 0.3400 - val_accuracy: 0.8631 - val_auc: 0.9342

# %%
# Plot loss and metrics
epochs = range(1, len(history.history['loss']) + 1)
def plot_metric(epochs, train_metric, val_metric, metric_name):
    plt.plot(epochs, train_metric, 'b', label=f'Training {metric_name}')
    plt.plot(epochs, val_metric, 'r', label=f'Testing {metric_name}')
    plt.title(f'Training vs Test {metric_name}')
    plt.xlabel("Epochs")
    plt.ylabel(metric_name)
    plt.legend()
    plt.grid(False)
    plt.show()

# %%
plot_metric(epochs, history.history['loss'], history.history['val_loss'], 'Loss')
plt.savefig('../images/model_loss.png')

# %%
plot_metric(epochs, history.history['accuracy'], history.history['val_accuracy'], 'Accuracy')
plt.savefig('../images/model_acc.png')

# %%
plot_metric(epochs, history.history['auc'], history.history['val_auc'], 'AUC')
plt.savefig('../images/model_auc.png')

# %%
# Evaluate the model
results = model.evaluate(X_test, y_test)
print(f'Val Loss: {results[0]:.2f}')
print(f'Val Accuracy: {results[1] * 100:.2f}%')
print(f'Val AUC: {results[2]:.4f}')
# Out:
# 91/91 [==============================] - 2s 21ms/step - loss: 0.3400 - accuracy: 0.8631 - auc: 0.9342
# Val Loss: 0.34
# Val Accuracy: 86.31%
# Val AUC: 0.9342

# %%
from keras.callbacks import ModelCheckpoint

filepath = "../models/best_model.h5"

# Create a ModelCheckpoint callback
checkpoint = ModelCheckpoint(filepath, monitor='val_auc', verbose=1, save_best_only=True, mode='max')

# Train the model 
history_1 = model.fit(X_train,
                    y_train, 
                    validation_data=(X_test, y_test),
                    epochs=50,
                    batch_size=32,
                    callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.8551 - auc: 0.9286
# Epoch 1: val_auc improved from -inf to 0.93606, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3409 - accuracy: 0.8551 - auc: 0.9286 - val_loss: 0.3231 - val_accuracy: 0.8614 - val_auc: 0.9361
# Epoch 2/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3353 - accuracy: 0.8593 - auc: 0.9309
# Epoch 2: val_auc improved from 0.93606 to 0.93757, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3353 - accuracy: 0.8593 - auc: 0.9309 - val_loss: 0.3207 - val_accuracy: 0.8617 - val_auc: 0.9376
# Epoch 3/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3404 - accuracy: 0.8547 - auc: 0.9285
# Epoch 3: val_auc did not improve from 0.93757
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3404 - accuracy: 0.8547 - auc: 0.9285 - val_loss: 0.3378 - val_accuracy: 0.8659 - val_auc: 0.9355
# Epoch 4/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.8589 - auc: 0.9314
# Epoch 4: val_auc did not improve from 0.93757
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3338 - accuracy: 0.8589 - auc: 0.9314 - val_loss: 0.3276 - val_accuracy: 0.8600 - val_auc: 0.9349
# Epoch 5/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3323 - accuracy: 0.8598 - auc: 0.9320
# Epoch 5: val_auc did not improve from 0.93757
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3323 - accuracy: 0.8598 - auc: 0.9320 - val_loss: 0.3426 - val_accuracy: 0.8475 - val_auc: 0.9282
# Epoch 6/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.8580 - auc: 0.9315
# Epoch 6: val_auc improved from 0.93757 to 0.93906, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3332 - accuracy: 0.8580 - auc: 0.9315 - val_loss: 0.3170 - val_accuracy: 0.8659 - val_auc: 0.9391
# Epoch 7/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.8623 - auc: 0.9340
# Epoch 7: val_auc did not improve from 0.93906
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3274 - accuracy: 0.8623 - auc: 0.9340 - val_loss: 0.3288 - val_accuracy: 0.8621 - val_auc: 0.9367
# Epoch 8/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3226 - accuracy: 0.8660 - auc: 0.9359
# Epoch 8: val_auc improved from 0.93906 to 0.94037, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3226 - accuracy: 0.8660 - auc: 0.9359 - val_loss: 0.3129 - val_accuracy: 0.8697 - val_auc: 0.9404
# Epoch 9/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.8627 - auc: 0.9361
# Epoch 9: val_auc improved from 0.94037 to 0.94073, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3222 - accuracy: 0.8627 - auc: 0.9361 - val_loss: 0.3112 - val_accuracy: 0.8690 - val_auc: 0.9407
# Epoch 10/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3246 - accuracy: 0.8635 - auc: 0.9353
# Epoch 10: val_auc did not improve from 0.94073
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3246 - accuracy: 0.8635 - auc: 0.9353 - val_loss: 0.3146 - val_accuracy: 0.8666 - val_auc: 0.9395
# Epoch 11/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3167 - accuracy: 0.8654 - auc: 0.9385
# Epoch 11: val_auc did not improve from 0.94073
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3167 - accuracy: 0.8654 - auc: 0.9385 - val_loss: 0.3383 - val_accuracy: 0.8673 - val_auc: 0.9362
# Epoch 12/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.8676 - auc: 0.9384
# Epoch 12: val_auc did not improve from 0.94073
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3169 - accuracy: 0.8676 - auc: 0.9384 - val_loss: 0.3313 - val_accuracy: 0.8572 - val_auc: 0.9361
# Epoch 13/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3145 - accuracy: 0.8691 - auc: 0.9393
# Epoch 13: val_auc improved from 0.94073 to 0.94187, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3145 - accuracy: 0.8691 - auc: 0.9393 - val_loss: 0.3149 - val_accuracy: 0.8711 - val_auc: 0.9419
# Epoch 14/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.8682 - auc: 0.9412
# Epoch 14: val_auc improved from 0.94187 to 0.94305, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3092 - accuracy: 0.8682 - auc: 0.9412 - val_loss: 0.3037 - val_accuracy: 0.8697 - val_auc: 0.9430
# Epoch 15/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3112 - accuracy: 0.8676 - auc: 0.9407
# Epoch 15: val_auc did not improve from 0.94305
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3112 - accuracy: 0.8676 - auc: 0.9407 - val_loss: 0.3135 - val_accuracy: 0.8669 - val_auc: 0.9419
# Epoch 16/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.8701 - auc: 0.9424
# Epoch 16: val_auc improved from 0.94305 to 0.94496, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3064 - accuracy: 0.8701 - auc: 0.9424 - val_loss: 0.3034 - val_accuracy: 0.8770 - val_auc: 0.9450
# Epoch 17/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8699 - auc: 0.9423
# Epoch 17: val_auc did not improve from 0.94496
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3069 - accuracy: 0.8699 - auc: 0.9423 - val_loss: 0.3052 - val_accuracy: 0.8711 - val_auc: 0.9434
# Epoch 18/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.8757 - auc: 0.9438
# Epoch 18: val_auc did not improve from 0.94496
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3027 - accuracy: 0.8757 - auc: 0.9438 - val_loss: 0.3100 - val_accuracy: 0.8714 - val_auc: 0.9434
# Epoch 19/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.8749 - auc: 0.9446
# Epoch 19: val_auc did not improve from 0.94496
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3003 - accuracy: 0.8749 - auc: 0.9446 - val_loss: 0.3172 - val_accuracy: 0.8711 - val_auc: 0.9413
# Epoch 20/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3054 - accuracy: 0.8697 - auc: 0.9429
# Epoch 20: val_auc improved from 0.94496 to 0.94505, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 38ms/step - loss: 0.3054 - accuracy: 0.8697 - auc: 0.9429 - val_loss: 0.3070 - val_accuracy: 0.8742 - val_auc: 0.9450
# Epoch 21/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8765 - auc: 0.9443
# Epoch 21: val_auc did not improve from 0.94505
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3005 - accuracy: 0.8765 - auc: 0.9443 - val_loss: 0.3136 - val_accuracy: 0.8676 - val_auc: 0.9420
# Epoch 22/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.8787 - auc: 0.9472
# Epoch 22: val_auc did not improve from 0.94505
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2935 - accuracy: 0.8787 - auc: 0.9472 - val_loss: 0.3268 - val_accuracy: 0.8565 - val_auc: 0.9346
# Epoch 23/50
# 271/271 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.8719 - auc: 0.9447
# Epoch 23: val_auc did not improve from 0.94505
# 271/271 [==============================] - 10s 37ms/step - loss: 0.3003 - accuracy: 0.8719 - auc: 0.9447 - val_loss: 0.2994 - val_accuracy: 0.8746 - val_auc: 0.9449
# Epoch 24/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8775 - auc: 0.9477
# Epoch 24: val_auc did not improve from 0.94505
# 271/271 [==============================] - 10s 38ms/step - loss: 0.2920 - accuracy: 0.8775 - auc: 0.9477 - val_loss: 0.3419 - val_accuracy: 0.8489 - val_auc: 0.9305
# Epoch 25/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.8787 - auc: 0.9489
# Epoch 25: val_auc did not improve from 0.94505
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2883 - accuracy: 0.8787 - auc: 0.9489 - val_loss: 0.3045 - val_accuracy: 0.8645 - val_auc: 0.9430
# Epoch 26/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8794 - auc: 0.9466
# Epoch 26: val_auc did not improve from 0.94505
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2946 - accuracy: 0.8794 - auc: 0.9466 - val_loss: 0.3461 - val_accuracy: 0.8708 - val_auc: 0.9395
# Epoch 27/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.8812 - auc: 0.9498
# Epoch 27: val_auc did not improve from 0.94505
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2863 - accuracy: 0.8812 - auc: 0.9498 - val_loss: 0.3058 - val_accuracy: 0.8680 - val_auc: 0.9431
# Epoch 28/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.8761 - auc: 0.9490
# Epoch 28: val_auc improved from 0.94505 to 0.94615, saving model to ../models/best_model.h5
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2883 - accuracy: 0.8761 - auc: 0.9490 - val_loss: 0.2990 - val_accuracy: 0.8763 - val_auc: 0.9462
# Epoch 29/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.8820 - auc: 0.9506
# Epoch 29: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2838 - accuracy: 0.8820 - auc: 0.9506 - val_loss: 0.2997 - val_accuracy: 0.8780 - val_auc: 0.9461
# Epoch 30/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2777 - accuracy: 0.8858 - auc: 0.9527
# Epoch 30: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2777 - accuracy: 0.8858 - auc: 0.9527 - val_loss: 0.2982 - val_accuracy: 0.8777 - val_auc: 0.9461
# Epoch 31/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.8815 - auc: 0.9516
# Epoch 31: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2810 - accuracy: 0.8815 - auc: 0.9516 - val_loss: 0.3006 - val_accuracy: 0.8742 - val_auc: 0.9454
# Epoch 32/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8819 - auc: 0.9509
# Epoch 32: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2832 - accuracy: 0.8819 - auc: 0.9509 - val_loss: 0.3011 - val_accuracy: 0.8732 - val_auc: 0.9452
# Epoch 33/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2751 - accuracy: 0.8853 - auc: 0.9537
# Epoch 33: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2751 - accuracy: 0.8853 - auc: 0.9537 - val_loss: 0.3141 - val_accuracy: 0.8711 - val_auc: 0.9437
# Epoch 34/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2720 - accuracy: 0.8846 - auc: 0.9548
# Epoch 34: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2720 - accuracy: 0.8846 - auc: 0.9548 - val_loss: 0.3051 - val_accuracy: 0.8784 - val_auc: 0.9437
# Epoch 35/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.8839 - auc: 0.9549
# Epoch 35: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 38ms/step - loss: 0.2711 - accuracy: 0.8839 - auc: 0.9549 - val_loss: 0.3116 - val_accuracy: 0.8805 - val_auc: 0.9440
# Epoch 36/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.8845 - auc: 0.9540
# Epoch 36: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 39ms/step - loss: 0.2736 - accuracy: 0.8845 - auc: 0.9540 - val_loss: 0.3102 - val_accuracy: 0.8798 - val_auc: 0.9439
# Epoch 37/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.8876 - auc: 0.9576
# Epoch 37: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 38ms/step - loss: 0.2635 - accuracy: 0.8876 - auc: 0.9576 - val_loss: 0.3029 - val_accuracy: 0.8791 - val_auc: 0.9453
# Epoch 38/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.8897 - auc: 0.9567
# Epoch 38: val_auc did not improve from 0.94615
# 271/271 [==============================] - 11s 39ms/step - loss: 0.2656 - accuracy: 0.8897 - auc: 0.9567 - val_loss: 0.3093 - val_accuracy: 0.8805 - val_auc: 0.9439
# Epoch 39/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2617 - accuracy: 0.8895 - auc: 0.9581
# Epoch 39: val_auc did not improve from 0.94615
# 271/271 [==============================] - 11s 39ms/step - loss: 0.2617 - accuracy: 0.8895 - auc: 0.9581 - val_loss: 0.3230 - val_accuracy: 0.8680 - val_auc: 0.9385
# Epoch 40/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.8898 - auc: 0.9589
# Epoch 40: val_auc did not improve from 0.94615
# 271/271 [==============================] - 11s 39ms/step - loss: 0.2593 - accuracy: 0.8898 - auc: 0.9589 - val_loss: 0.3157 - val_accuracy: 0.8780 - val_auc: 0.9417
# Epoch 41/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.8906 - auc: 0.9594
# Epoch 41: val_auc did not improve from 0.94615
# 271/271 [==============================] - 11s 39ms/step - loss: 0.2572 - accuracy: 0.8906 - auc: 0.9594 - val_loss: 0.3354 - val_accuracy: 0.8787 - val_auc: 0.9402
# Epoch 42/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2515 - accuracy: 0.8932 - auc: 0.9614
# Epoch 42: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 39ms/step - loss: 0.2515 - accuracy: 0.8932 - auc: 0.9614 - val_loss: 0.3285 - val_accuracy: 0.8638 - val_auc: 0.9371
# Epoch 43/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2558 - accuracy: 0.8890 - auc: 0.9599
# Epoch 43: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 38ms/step - loss: 0.2558 - accuracy: 0.8890 - auc: 0.9599 - val_loss: 0.3288 - val_accuracy: 0.8676 - val_auc: 0.9359
# Epoch 44/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2526 - accuracy: 0.8922 - auc: 0.9610
# Epoch 44: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2526 - accuracy: 0.8922 - auc: 0.9610 - val_loss: 0.3134 - val_accuracy: 0.8746 - val_auc: 0.9410
# Epoch 45/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2486 - accuracy: 0.8934 - auc: 0.9621
# Epoch 45: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2486 - accuracy: 0.8934 - auc: 0.9621 - val_loss: 0.3248 - val_accuracy: 0.8718 - val_auc: 0.9378
# Epoch 46/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.8969 - auc: 0.9636
# Epoch 46: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2439 - accuracy: 0.8969 - auc: 0.9636 - val_loss: 0.3527 - val_accuracy: 0.8773 - val_auc: 0.9401
# Epoch 47/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.8984 - auc: 0.9649
# Epoch 47: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2394 - accuracy: 0.8984 - auc: 0.9649 - val_loss: 0.3432 - val_accuracy: 0.8617 - val_auc: 0.9331
# Epoch 48/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.8956 - auc: 0.9638
# Epoch 48: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2434 - accuracy: 0.8956 - auc: 0.9638 - val_loss: 0.3387 - val_accuracy: 0.8683 - val_auc: 0.9359
# Epoch 49/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.8972 - auc: 0.9636
# Epoch 49: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2439 - accuracy: 0.8972 - auc: 0.9636 - val_loss: 0.3358 - val_accuracy: 0.8576 - val_auc: 0.9330
# Epoch 50/50
# 271/271 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9010 - auc: 0.9673
# Epoch 50: val_auc did not improve from 0.94615
# 271/271 [==============================] - 10s 37ms/step - loss: 0.2308 - accuracy: 0.9010 - auc: 0.9673 - val_loss: 0.3365 - val_accuracy: 0.8704 - val_auc: 0.9382

# %%
# Plot the loss and metics
epochs = range(1, len(history_1.history['loss']) + 1)
plot_metric(epochs, history_1.history['loss'], history_1.history['val_loss'], 'Loss')
plt.savefig('../images/best_model_loss.png')

# %%
plot_metric(epochs, history_1.history['accuracy'], history_1.history['val_accuracy'], 'Accuracy')
plt.savefig('../images/best_model_acc.png')

# %%
plot_metric(epochs, history_1.history['auc'], history_1.history['val_auc'], 'AUC')
plt.savefig('../images/best_model_auc.png')

# %% [markdown]
# #### Model Evaluation

# %%
from keras.models import load_model

filepath = "../models/best_model.h5"

# Load best model
best_model = load_model(filepath)

# Evaluate the model
results = best_model.evaluate(X_test, y_test)
print(f'Val Loss: {results[0]:.2f}')
print(f'Val Accuracy: {results[1] * 100:.2f}%')
print(f'Val AUC: {results[2]:.4f}')
# Out:
# 2023-09-26 16:00:43.499494: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-09-26 16:00:43.604684: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-09-26 16:00:43.690734: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 91/91 [==============================] - 2s 21ms/step - loss: 0.2990 - accuracy: 0.8763 - auc: 0.9462
# Val Loss: 0.30
# Val Accuracy: 87.63%
# Val AUC: 0.9462

# %%
predictions = best_model.predict(X_test)
predicted_labels = np.argmax(predictions, axis=1)
# Convert one-hot encoded labels back to original form
y_test_original = np.argmax(y_test, axis=1)
predicted_labels_original = np.argmax(predictions, axis=1)

# Generate confusion matrix
cf = confusion_matrix(y_test_original, predicted_labels_original)
label_name=["negative","Positive"]

plt.figure(figsize=(6,5))
sns.heatmap(cf,annot=True,fmt="d",cmap="Blues",xticklabels=label_name,yticklabels=label_name)
all_sample_title = f'Accuracy Score for LSTM Classifier: {results[1]:.4}'
plt.title(all_sample_title, size = 15)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# 91/91 [==============================] - 1s 11ms/step

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test_original, predictions[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='AUC = {:.4f}'.format(results[2]))
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend()
plt.show()

# %% [markdown]
# #### Model Predictions

# %%
# Make predictions
predictions = best_model.predict(X_test)

# Predictions willl be probability scores for each clas, so you can covnert them to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Create list of positive and negative snetences based on predicted labels 
positive_sentences = [X_test[i] for i in range(len(predicted_labels)) if predicted_labels[i] == 1]
negative_sentences = [X_test[i] for i in range(len(predicted_labels)) if predicted_labels[i] == 0]

positive_texts = [tokenizer.sequences_to_texts([sentence])[0] for sentence in positive_sentences]
negative_texts = [tokenizer.sequences_to_texts([sentence])[0] for sentence in negative_sentences]

print("Postive Text")
positive_texts[:5]
# Out:
# 2023-09-08 22:17:42.314133: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-09-08 22:17:42.388034: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-09-08 22:17:42.470171: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 91/91 [==============================] - 1s 11ms/step
# Postive Text
# ['jetblue great flight great view http co yxn00pnoav',
#  'americanair great thanks followed',
#  'united got thanks',
#  'virginamerica look like broken link asset http co oardjjgrrd',
#  'jetblue a320 pulling gate sunrise bostonlogan morning jetbluesofly jetblue airbus http co jgdu5us8dz']

# %%
print("Negative Text")
negative_texts[:5]
# Out:
# Negative Text
# ['usairways charged flight cancelled flightled unbelievable unheard',
#  'united actually gate agent rude standing line waiting reflight booking problem missed flight sti awful',
#  'americanair worry called back 4 hr late flightr asleep took additional 200 fee aa standard everything gr8',
#  'united thank one month ago none weird club one busiest airport u',
#  'united brother luggage lost copa airline flight 635 competing sunday 2015 panamerican cross country cup please help']
